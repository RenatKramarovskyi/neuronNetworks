# 0  322.130005  3676100
# 1  313.480011  4911300
# 2  311.880005  4911000
# 3  315.179993  5953300
# 4  312.029999  5660700
# 5  308.470001  4553100
# 6  311.790009  3479500

# %%
import numpy as np
first_course_marks = np.random.randint(low=30, high=100, size=(1,60)).flatten()
second_course_marks = np.random.randint(low=40, high=100, size=(1,60)).flatten()
# average = [(first_course_marks[i] + second_course_marks[i]) / 2 for i in range(0, len(first_course_marks))]
# average = [(x + y) / 2 for x, y in zip(first_course_marks, second_course_marks)]
average = (first_course_marks + second_course_marks) / 2
own_df = pd.DataFrame({'Fisrt course : ' : first_course_marks[:], 'Second course : ' : second_course_marks[:], 'Average : ' : average[:]})
# print(own_df)
own_df.to_csv('own_df.csv', index=True)
own_df
# Out:
#     Fisrt course :   Second course :   Average :
# 0                97                61        79.0
# 1                77                76        76.5
# 2                79                53        66.0
# 3                46                85        65.5
# 4                81                75        78.0
# 5                37                44        40.5
# 6                31                61        46.0
# 7                43                81        62.0
# 8                93                69        81.0
# 9                50                53        51.5
# 10               42                74        58.0
# 11               96                64        80.0
# 12               43                87        65.0
# 13               58                66        62.0
# 14               68                61        64.5
# 15               87                66        76.5
# 16               76                98        87.0
# 17               38                57        47.5
# ...

# %% [markdown]
# # task 10, graph

# %%
import plotly.express as pe
canv = pe.line(df, x='Date', y='Volume')
canv.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
temp = df[df["High"].astype('int') == 368]
canv = pe.line(temp, x='Date', y=['High', 'Low'] )
canv.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
temp = df[df["High"].astype('int') != 368]
canv = pe.line(temp, x='Date', y=['High', 'Low'] )
canv.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
temp = df[df["Date"].isin(["2023-02-01", "2023-02-10", "2023-02-07"])]
canv = pe.line(temp, x='Date', y='Volume')
canv.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
temp = df[(df["Date"] >= "2023-02-28") & (df["Date"] <= "2023-03-22")]
canv = pe.line(temp, x='Date', y=['High', 'Low', 'Close', 'Open'])
canv.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
temp = df[(df["Volume"] >= 2000000) & (df["Volume"] <= 4000000)]
canv = pe.line(temp, x='Date' ,y='Volume')
canv.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as pe
df = pd.read_csv('Iris.csv')
df
canv = pe.scatter_3d(df, x='SepalLengthCm', y='PetalLengthCm', z='PetalWidthCm', color='Species')
canv.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import pandas as pd
import plotly.express as pe
import tensorflow as tsf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split



df = pd.read_csv('alarms.csv')
# df
canv = pe.scatter_3d(df, x='sound', y='distance', z='alarm')
# canv = pe.scatter_3d(df, x='sound', y='visibility', z='alarm')
canv.show()
# obviously alarm more then, when more soud and less distance
# or alarm more then, twhen soun and visibility more

X = df[['sound', 'distance', 'visibility']].values
Y = df['alarm'].values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3) #70\30 train\test

model = models.Sequential([
    layers.Dense(1, input_shape=(X_train.shape[1],), activation='sigmoid')
])

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mse'])

model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_data=(X_test, Y_test))

loss, accuracy = model.evaluate(X_test, Y_test)
print(f"""
    Total test lost : {loss}
Total test accuracy : {accuracy}
""")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 'sound', 'distance', 'visibility'

new_set = np.array([
    [0.8, 0.1, 0.1],
    [0.3, 0.7, 0.1],
    [0.4, 0.6, 0.5],
    [0.9, 0.07, 0.8],
    [0.1, 0.8, 0.9],
    [0.1, 0.9, 0.1]
])

predictions = model.predict(new_set)
print(predictions)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[0.49424022]
#  [0.34704828]
#  [0.43374524]
#  [0.619222  ]
#  [0.43511593]
#  [0.2999902 ]]
